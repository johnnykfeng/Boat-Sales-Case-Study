# %%
# %%capture
# !pip install pandas_profiling

# %%
import pandas_profiling
import pandas as pd

# %%
boat_df_b = pd.read_csv('useful_boat_data.csv')

# %%
boat_df_b.columns
# Out:
# Index(['Unnamed: 0', 'Number of views last 7 days', 'Price', 'currency',
#        'amount', 'Price_Euros', 'Boat Type', 'Manufacturer', 'Type',
#        'Condition', 'Year Built', 'Length', 'Width', 'Size', 'Material',
#        'Location', 'Country'],
#       dtype='object')

# %%
# cols = ['Number of views last 7 days', 'currency',
#        'amount', 'Price_Euros', 'Boat Type', 'Manufacturer', 
#         'Year Built', 'Length', 'Width', 'Material', 'Country']

# %%
# boat_df_b = pd.read_csv('new_boat_data.csv', usecols=cols)

# %%
report = pandas_profiling.ProfileReport(boat_df_b)

# %%
profile = boat_df_b.profile_report(title='first report')

# %%
profile.to_file(output_file = 'first_report.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
report.to_file(output_file = 'output.html')
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
